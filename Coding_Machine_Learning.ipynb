# %% [markdown]
# <a href="https://colab.research.google.com/github/FreshWaterLee/Personal_Stduy_Deep/blob/main/Coding_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
## TeachableMachine.googlewith.com 을 통해서 굳이 파이썬을 이용한 커스텀 모델을 작성할 필요는 없다.
## (이미지, 소리, 포즈 기반 모델 작성이 가능)
## 웹페이지를 통해 모델 제작이 가능(많은 라벨링(클래스)을 하면 어떻게 될까?)
## Export Model을 이용해 작성한 모델을 다운 받을수있음

# %%
## Model이란? 다양한 데이터(경험)을 통해 나온 특성(깨달음)을 판단하는 기준

# %%
## 머신러닝에서 표(Table)란? DataSeT이라고 부르기에 
##머신러닝 직업분야에서 말하는 DataSet이란 객체의 데이터가 있는 표를 뜻함
## 행(가로), 열(세로)
## 개체, 관측치, 기록, 사례, 경우 <-가로(행)
## 특성, 속성, 변수, 필드 <- 세로(열)

# %% [markdown]
# ![표(데이터셋).JPG](data:image/jpeg;base64,...)

# %%
## 위의 예로 온도 변화(독립변수)를 통해 발생한 판매량(종속변수)의 변화
## 독립변수와 종속 변수
## 데이터를 데이터셋에 저장하는것만 중요한게 아니다
## !!본인이 원하는 데이터를 분류할수 있어야한다!!
## 독립 변수란? 원인이 되는 열(세로)
## 종속 변수란? 독립변수(원인)의 영향을 받는 결과를 나타내는 열(세로)
## 독립 변수와 종속 변수의 관계를 인과관계라 한다.
## 인과 관계는 상관관계에 포함이 된다.

# %%
## 머신러닝의 분류
## ↓의 그림을 참고하시오 (크게 분류하면 이렇게 나누어진다 절대적 분류는 아닙니다.)

# %% [markdown]
# ![머신러닝의 종류.JPG](data:image/jpeg;base64,...)

# %%
## 지도 학습이란?
## 기계를 가르치는 학습

## 비지도 학습이란?
## 기계에게 통찰을 통해 새로운 의미나 관계를 깨닫게하는것(가르침을 주지않고 기계 스스로 깨닫게하는 학습)

## 강화 학습이란?
## 지도 학습과 비슷하지만, 반복 학습을 통해 더 빠른 or 좋은 결과를 찾을수 있게 학습시키는것

# %%
## 지도학습에 대한 상세한 설명
## 과거의 데이터를 독립변수(원인)와 종속변수(결과)를 학습시켜서 
## 새로운 독립변수의 종속변수를 컴퓨터가 스스로 연산하도록 하는 학습

# %%
## 회귀와 분류
## 회귀란 예측하는것(숫자를 알아내고싶다면)
## 예시 : 연령 별 평균 키, 온도에 따른 아이스크림 판매량, 

## 분류란 특정하는것(이름, 문자를 추측하고 싶다면)
## 예시 : 신체 검사를 통한 군복무 여부(현역,공익,면제), 공부시간에 따른 합격 불합격 여부

# %%
## 비지도 학습에 대한 설명

## 군집화 란?
## 유사 값을 그룹으로 분류하는 것
## 즉 미지의 값과 유사한 값을 가진 그룹으로 분류 하는것
## 예시 : 20~29세를 20대 그룹으로 지정-> 이런 21~29를 모아두는 행위를 군집화란 한다.

## 연관 규칙 학습(장바구니 학습) 이란?
## 하나를 선택하면 같이 선택되는 관계를 연관이 된다라고 한다.
## 예시 : 메시를 검색하면 호날두에 대한 정보도 같이 나오는 상황 -> 메시와 호날두는 서로 연관되있다 라 말할수있다.
## 참고로 이전까지 추천이란 단어가 들어간 기술에 사용된 학습이 연관 규칙 학습이었다.

## 비지도 학습 
## 데이터를 정리정돈 해서 표(데이터셋)의 데이터를 정의하는 것을 뜻함

# %%
## 강화 학습이란?
## 대표적 강화학습의 결과물은 알파고(Alpha Go)라 할 수 있다.
## 셀수 없이 많은 사이버 바둑을 플레이 하면서 어떠한 상황에서도 이길수 있는 바둑을 하도록 학습시켰다.
## 상태에 따른 최고의 보상을 얻을수 있도록 하는 것

# %%
## 머신 러닝에서 학습을 선택 흐름도

# %% [markdown]
# ![학습_선택법.JPG](data:image/jpeg;base64,...)

# %%
##
