# %% [markdown]
# <a href="https://colab.research.google.com/github/FreshWaterLee/Personal_Stduy_Deep/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np

# %%
img = image.load_img('/content/drive/MyDrive/cnn/Train/Cat/39395293592_2ae5fd2026_n.jpg')

# %%
plt.imshow(img)
cv2.imread('/content/drive/MyDrive/cnn/Train/Cat/39395293592_2ae5fd2026_n.jpg').shape
# Out:
# (238, 320, 3)

# %%
#340 320
train = ImageDataGenerator(rescale=1/255)##
validation = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train.flow_from_directory('/content/drive/MyDrive/cnn/Train/',target_size=(200,200),batch_size=3,class_mode ='binary' ) ## Train DataSet을 만들 라이브러리 설정( 라벨링 폴더에 이미지를 넣어놓아야 분류를 할수있다. )
validation_dataset = train.flow_from_directory('/content/drive/MyDrive/cnn/Test/',target_size=(200,200),batch_size=3,class_mode ='binary' ) ## Validation_DataSet 라이브러리 설정
# Out:
# Found 225 images belonging to 3 classes.
# Found 45 images belonging to 3 classes.

# %%
train_dataset.class_indices ## 라벨링한 이름과, 프로그램에서 판단할 상수
# Out:
# {'Cat': 0, 'Dog': 1, 'Tiger': 2}

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation='relu',input_shape=(200,200,3)),
                                    tf.keras.layers.MaxPooling2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D(2,2),
                                    #
                                    tf.keras.layers.Flatten(),
                                    ##
                                    tf.keras.layers.Dense(512,activation='relu'),
                                    tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy'])

# %%
model.fit = model.fit(train_dataset,
                      steps_per_epoch=5,
                      epochs=30,
                      validation_data= validation_dataset
                      )
# Out:
# Epoch 1/30
# 5/5 [==============================] - 20s 4s/step - loss: 4.1668 - accuracy: 0.2000 - val_loss: -0.5211 - val_accuracy: 0.3333
# Epoch 2/30
# 5/5 [==============================] - 5s 923ms/step - loss: -3.2882 - accuracy: 0.4667 - val_loss: -3.7198 - val_accuracy: 0.3333
# Epoch 3/30
# 5/5 [==============================] - 5s 1s/step - loss: -7.4239 - accuracy: 0.3333 - val_loss: -16.7879 - val_accuracy: 0.3333
# Epoch 4/30
# 5/5 [==============================] - 4s 823ms/step - loss: 7.0636 - accuracy: 0.3333 - val_loss: -26.0608 - val_accuracy: 0.3333
# Epoch 5/30
# 5/5 [==============================] - 4s 739ms/step - loss: 11.8655 - accuracy: 0.3333 - val_loss: -29.0413 - val_accuracy: 0.3333
# Epoch 6/30
# 5/5 [==============================] - 5s 817ms/step - loss: -24.2316 - accuracy: 0.5333 - val_loss: -42.0273 - val_accuracy: 0.3333
# Epoch 7/30
# 5/5 [==============================] - 5s 900ms/step - loss: 11.6926 - accuracy: 0.2667 - val_loss: -41.3950 - val_accuracy: 0.3333
# Epoch 8/30
# 5/5 [==============================] - 5s 849ms/step - loss: 82.7533 - accuracy: 0.4000 - val_loss: -27.9270 - val_accuracy: 0.3333
# Epoch 9/30
# 5/5 [==============================] - 4s 672ms/step - loss: -9.6196 - accuracy: 0.5333 - val_loss: -34.0558 - val_accuracy: 0.3333
# Epoch 10/30
# 5/5 [==============================] - 3s 705ms/step - loss: -13.1893 - accuracy: 0.3333 - val_loss: -38.5141 - val_accuracy: 0.3333
# Epoch 11/30
# 5/5 [==============================] - 4s 716ms/step - loss: 2.1081 - accuracy: 0.3333 - val_loss: -34.4256 - val_accuracy: 0.3333
# Epoch 12/30
# 5/5 [==============================] - 4s 688ms/step - loss: -21.6980 - accuracy: 0.4000 - val_loss: -48.9439 - val_accuracy: 0.3333
# Epoch 13/30
# 5/5 [==============================] - 3s 642ms/step - loss: -179.5609 - accuracy: 0.2667 - val_loss: -157.9276 - val_accuracy: 0.3333
# Epoch 14/30
# 5/5 [==============================] - 4s 745ms/step - loss: 123.9318 - accuracy: 0.3333 - val_loss: -152.0261 - val_accuracy: 0.3333
# Epoch 15/30
# 5/5 [==============================] - 3s 644ms/step - loss: -1021.5847 - accuracy: 0.2000 - val_loss: -429.3946 - val_accuracy: 0.3333
# Epoch 16/30
# 5/5 [==============================] - 3s 616ms/step - loss: 26.2605 - accuracy: 0.4667 - val_loss: -482.3918 - val_accuracy: 0.3333
# Epoch 17/30
# 5/5 [==============================] - 3s 606ms/step - loss: 1080.5565 - accuracy: 0.2667 - val_loss: -595.7819 - val_accuracy: 0.3333
# Epoch 18/30
# 5/5 [==============================] - 3s 628ms/step - loss: -8896.3809 - accuracy: 0.4667 - val_loss: -893.9338 - val_accuracy: 0.3333
# Epoch 19/30
# 5/5 [==============================] - 3s 685ms/step - loss: -2899.2844 - accuracy: 0.2000 - val_loss: -978.7236 - val_accuracy: 0.3333
# Epoch 20/30
# 5/5 [==============================] - 4s 642ms/step - loss: -14995.2148 - accuracy: 0.3333 - val_loss: -976.8477 - val_accuracy: 0.3333
# Epoch 21/30
# 5/5 [==============================] - 3s 632ms/step - loss: -8234.0830 - accuracy: 0.2000 - val_loss: -1000.4548 - val_accuracy: 0.3333
# Epoch 22/30
# 5/5 [==============================] - 4s 620ms/step - loss: 17400.6250 - accuracy: 0.2667 - val_loss: -1157.3092 - val_accuracy: 0.3333
# Epoch 23/30
# 5/5 [==============================] - 3s 663ms/step - loss: -1494.1333 - accuracy: 0.2667 - val_loss: -1173.4705 - val_accuracy: 0.3333
# Epoch 24/30
# 5/5 [==============================] - 3s 607ms/step - loss: -2652.1968 - accuracy: 0.2667 - val_loss: -1257.4585 - val_accuracy: 0.3333
# Epoch 25/30
# 5/5 [==============================] - 3s 615ms/step - loss: -30782.6250 - accuracy: 0.2667 - val_loss: -1197.5164 - val_accuracy: 0.3333
# Epoch 26/30
# 5/5 [==============================] - 3s 618ms/step - loss: -7844.7754 - accuracy: 0.4000 - val_loss: -1329.4302 - val_accuracy: 0.3333
# Epoch 27/30
# 5/5 [==============================] - 3s 654ms/step - loss: 26134.4375 - accuracy: 0.3333 - val_loss: -1595.5630 - val_accuracy: 0.3333
# Epoch 28/30
# 5/5 [==============================] - 3s 602ms/step - loss: -12169.7559 - accuracy: 0.2000 - val_loss: -1633.0320 - val_accuracy: 0.3333
# Epoch 29/30
# 5/5 [==============================] - 3s 609ms/step - loss: -21554.5293 - accuracy: 0.2000 - val_loss: -1617.7722 - val_accuracy: 0.3333
# Epoch 30/30
# 5/5 [==============================] - 3s 610ms/step - loss: -10427.9346 - accuracy: 0.2667 - val_loss: -1754.3470 - val_accuracy: 0.3333

# %%
dir_path = '/content/drive/MyDrive/cnn/testImage/'

for i in os.listdir(dir_path):
    imgg = image.load_img(dir_path+'/'+i)
    plt.imshow(imgg)
    plt.show()

    X = image.img_to_array(imgg)
    X = np.expand_dims(X,axis=0)
    # images = np.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-3106ad4ba522> in <module>()
#       7
#       8     X = image.img_to_array(imgg)
# ----> 9     X = np.expand.dims(X,axis=0)
#      10     # images = np.
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     213             else:
#     214                 raise AttributeError("module {!r} has no attribute "
# --> 215                                      "{!r}".format(__name__, attr))
#     216
#     217         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'expand'
